# %%
# %pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !kaggle datasets download -d mlg-ulb/creditcardfraud -p ../data/raw --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# ...
#   0%|          | 0.00/66.0M [00:00<?, ?B/s]
#   2%|▏         | 1.00M/66.0M [00:00<00:41, 1.62MB/s]
#   3%|▎         | 2.00M/66.0M [00:00<00:27, 2.43MB/s]
#   5%|▍         | 3.00M/66.0M [00:01<00:22, 2.89MB/s]
#   6%|▌         | 4.00M/66.0M [00:01<00:20, 3.18MB/s]
#   8%|▊         | 5.00M/66.0M [00:01<00:18, 3.38MB/s]
#   9%|▉         | 6.00M/66.0M [00:02<00:18, 3.48MB/s]
#  11%|█         | 7.00M/66.0M [00:02<00:17, 3.55MB/s]
#  12%|█▏        | 8.00M/66.0M [00:02<00:16, 3.61MB/s]
#  14%|█▎        | 9.00M/66.0M [00:02<00:16, 3.65MB/s]
#  15%|█▌        | 10.0M/66.0M [00:03<00:16, 3.66MB/s]
#  17%|█▋        | 11.0M/66.0M [00:03<00:15, 3.63MB/s]
#  18%|█▊        | 12.0M/66.0M [00:03<00:15, 3.61MB/s]
#  20%|█▉        | 13.0M/66.0M [00:04<00:15, 3.59MB/s]
#  21%|██        | 14.0M/66.0M [00:04<00:15, 3.60MB/s]
#  23%|██▎       | 15.0M/66.0M [00:04<00:14, 3.59MB/s]
# ...

# %%
import pandas as pd
import numpy as np
import kagglehub

df_raw = pd.read_csv("../data/raw/creditcard.csv")
df = df_raw.copy()

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df[['Time', 'Amount', 'Class']].head(10)
# Out:
#    Time  Amount  Class
# 0   0.0  149.62      0
# 1   0.0    2.69      0
# 2   1.0  378.66      0
# 3   1.0  123.50      0
# 4   2.0   69.99      0
# 5   2.0    3.67      0
# 6   4.0    4.99      0
# 7   7.0   40.80      0
# 8   7.0   93.20      0
# 9   9.0    3.68      0

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.duplicated(subset=df.columns.tolist()).sum()
# Out:
# 1081

# %%
df.drop_duplicates(subset=df.columns.tolist(), inplace=True)

# %%
fraud_rate = df['Class'].mean() / 100
print(f"Fraud Rate: {fraud_rate:.6%}")
# Out:
# Fraud Rate: 0.001667%

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

px.pie(df, names='Class', title='Fraud Distribution').show()

# %%
px.box(df, x='Class', y='Amount', title='Transaction Amount by Class').show()

# %%
px.line(df, x='Time', y='Amount', color='Class', title='Transaction Amount Over Time').show()

# %% [markdown]
# Fraudulent transactions generally spend way less than normal transactions (try to remain hidden) and only make up a very small fraction of all transactions (0.167%)

# %%
df.corr()['Class'].abs().sort_values(ascending=False)
# Out:
# Class     1.000000
# V17       0.313498
# V14       0.293375
# V12       0.250711
# V10       0.206971
# V16       0.187186
# V3        0.182322
# V7        0.172347
# V11       0.149067
# V4        0.129326
# V18       0.105340
# V1        0.094486
# V9        0.094021
# V5        0.087812
# V2        0.084624
# V6        0.043915
# V19       0.033631
# V8        0.033068
# V21       0.026357
# V27       0.021892
# V20       0.021486
# Time      0.012359
# V28       0.009682
# V24       0.007210
# V23       0.006333
# Amount    0.005777
# V22       0.004887
# V26       0.004265
# V13       0.003897
# V15       0.003300
# V25       0.003202
# Name: Class, dtype: float64

# %%
px.imshow(df.corr(), text_auto=True, title='Correlation Matrix').show()

# %% [markdown]
# V features are pca components (vectors) and cannot be interpreted in a business setting
#
# V17, V14, V12 are the highest three correlated features with Fraud

# %%
df = df.sort_values('Time')
train_end = int(len(df) * 0.70)
val_end = int(len(df) * 0.85)

train_df = df.iloc[:train_end]
val_df = df.iloc[train_end:val_end]
test_df = df.iloc[val_end:]

# %% [markdown]
# Time validation used to split data instead of random spliting to avoid leakage.
#
# Oldest data used for training, and newer data used for validation and testing.

# %%
train_df.to_csv("../data/processed/train.csv", index=False)
val_df.to_csv("../data/processed/val.csv", index=False)
test_df.to_csv("../data/processed/test.csv", index=False)
